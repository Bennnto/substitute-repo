# %%
import requests

api_key = "89c11753aa0990a3ae145612cf91a90c"
url = f"https://api.openweathermap.org/data/2.5/weather?q=London&appid={api_key}"

response = requests.get(url)
print(response.json())
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 284.03, 'feels_like': 283.58, 'temp_min': 282.86, 'temp_max': 285.1, 'pressure': 1023, 'humidity': 92, 'sea_level': 1023, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 0.45, 'deg': 355, 'gust': 0.89}, 'clouds': {'all': 3}, 'dt': 1759098468, 'sys': {'type': 2, 'id': 2075535, 'country': 'GB', 'sunrise': 1759038975, 'sunset': 1759081555}, 'timezone': 3600, 'id': 2643743, 'name': 'London', 'cod': 200}
