# %%
import os


cwd = os.getcwd()
print(cwd)
os.chdir("/users/benpromkaew")
print('change directory to home', os.getcwd())
#Verified that directory exist
print(os.path.exists("/users/benpromkaew/Code")) #return True 
#mkdir
#os.mkdir("/users/benpromkaew/Testtest")
#print(os.path.exists("users/benpromkaew/Testtest"))
# Out:
# /Users/benpromkaew/Code/Python/Test
# change directory to home /Users/benpromkaew
# True

# %%
import os
import datetime
#remove directory
#os.rmdir("/users/benpromkaew/Testtest")
#---------------------------------------
# Get last modified date time os.path.getmtime (modified time)
modified = os.path.getmtime('/users/benpromkaew/Code/Python/Practice/Guess_number.py')
print(modified)
time = datetime.datetime.fromtimestamp(modified).strftime("%d-%m-%y %H:%M:%S")
print('Last Modified Time is', time)

#---------------------------------------
# Get last access Time
Last_a = os.path.getatime('/users/benpromkaew/Code/Python/Practice/Guess_number.py')
print(Last_a)
time_a = datetime.datetime.fromtimestamp(Last_a).strftime("%d-%m %H:%M:%S")
print('Last Access Time is', time_a)
# Out:
# 1758242205.413473
# Last Modified Time is 18-09-25 20:36:45
# 1759364361.712431
# Last Access Time is 01-10 20:19:21

# %% [markdown]
# Q1. Write a program to get and change the Current Working Directory to ‘/Users/apple/PythonProjects/Calculator’.

# %%
import os 

get_path=os.getcwd()
new_path=os.chdir('‘/Users/apple/PythonProjects/Calculator')
print(new_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 4
#       1 import os
#       3 get_path=os.getcwd()
# ----> 4 new_path=os.chdir('‘/Users/apple/PythonProjects/Calculator')
#       5 print(new_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '‘/Users/apple/PythonProjects/Calculator'

# %%
Q2. Write a program to list all files and directories present inside the directory “/Users/apple/PythonProjects”.

# %%
import os 
full_path = (os.listdir('/Users/apple/PythonProjects'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 2
#       1 import os
# ----> 2 full_path = (os.listdir('/Users/apple/PythonProjects'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/apple/PythonProjects'

# %% [markdown]
# Q3. Write a program to create a new directory “/Users/apple/PythonProjects/PythonGeeks2”.

# %%
import os

os.mkdir("Users/apple/PythonProjects/PythonGreek2")
print("created")

# %%
import os

#Check if'sexist
exists = os.path.exists('/Users/benpromkaew/PythonProjects/PythonGeeks2')
if exists == True:
    os.rmdir('/Users/benpromkaew/PythonProjects/PythonGeeks2')
    print('Deleted')
else :
    os.mkdir('/Users/benpromkaew/PythonProjects/PythonGeeks2')
    print('Make Directory')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 9
#       7     print('Deleted')
#       8 else :
# ----> 9     os.mkdir('/Users/benpromkaew/PythonProjects/PythonGeeks2')
#      10     print('Make Directory')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/benpromkaew/PythonProjects/PythonGeeks2'

# %% [markdown]
# Q4. Write a program to delete a directory “/Users/apple/PythonProjects/PythonGeeks2” if it exists, otherwise, create that directory.

# %%
import os.path

print(os.path.getsize(os.getcwd()))
# Out:
# 3168

# %%
from pathlib import Path, PurePath
import os


os.chdir('/Users/benpromkaew/Code/Python/Test')

Home = Path.home()
Curr = Path('.')
print(Home, Curr)


p = Path('/Users/benpromkaew/Code/Python/Practice')
print(p.name)
print(p.parent)
print(p.parts)

join_path = Path('Practice').joinpath('text.py')
print(join_path)

path_exists = Path('/Users/benpromkaew/Code/Python/Practice').exists()
print(path_exists)

list_file = Path('/Users/benpromkaew/Code/Python/Practice').iterdir()
print(list_file)

Path('/Users/benpromkaew/Code/Python/Practice/app.py').read_text()

with open ('/Users/benpromkaew/Code/Python/Practice/app.py', 'r') as f:
    print(f.read())

Path('/')
# Out:
# /Users/benpromkaew .
# Practice
# /Users/benpromkaew/Code/Python
# ('/', 'Users', 'benpromkaew', 'Code', 'Python', 'Practice')
# Practice/text.py
# True
# ...
# import random
# print('Hey ! Welcome to Number Guessing Game')
#
# print('Instruction!\n' + 'you have 5 chance to guessing the random number by input Range of number you would like to guess')
#
# def chk_range():
#     print('Please Enter Number in positive(+) integer value of range of number to random')
#     try:
#         print('Enter Lower bound')
#         low = input('>')
#         low = int(low)
#         print('Enter Higher bound')
#         high = input('>')
#     except ValueError :
#         print('Incorrect number format')
#         return None
#
# # check if high - low bound is in correct format of number of not
#     if low < 0 or high < 0 :
#     print ('low and high number should be positive value')
#         return None
#
#     if low > high :
#     print('lower bound should less than higher bound')
# ...
